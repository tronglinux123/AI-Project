# %% [markdown]
# <a href="https://colab.research.google.com/github/tronglinux123/AI-Project/blob/main/cxrretrieval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import timedelta
import os

import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from IPython.display import display, HTML, Image
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams.update({'font.size': 20})

# Access data using Google BigQuery.
from google.colab import auth
from google.cloud import bigquery
from google.colab import files

# %%
auth.authenticate_user()
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set up environment variables
project_id = 'project-physionet-data'
os.environ["GOOGLE_CLOUD_PROJECT"] = project_id

# Read data from BigQuery into pandas dataframes.
def run_query(query, project_id=project_id):
  return pd.io.gbq.read_gbq(
      query,
      project_id=project_id,
      dialect='standard')

# set the dataset
dataset = 'mimiciv'

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/processed_data.csv'
data = pd.read_csv(file_path)

# %%
data['dicom'] = data['file_name'].str.replace('.jpg', '')

# %%
data.head()
# Out:
#    Unnamed: 0                                         file_name         0  \
# 0           0  91ea24c1-ddf8f918-0c579885-c0bf36ed-3a2b306a.jpg -1.920675
# 1           1  35469b32-ecaab79e-6029f852-160bd61a-9e39d5bb.jpg  0.088068
# 2           2  15a9cb0e-a198aa68-69378bf4-b2b1c36c-fd8020c2.jpg -0.521883
# 3           3  884910a8-5d7a8bbd-1d59d71f-a97fa282-f7b9850f.jpg  0.401914
# 4           4  ebdae94d-7ace4119-3ca77b0b-bc8b0cd9-77429e52.jpg -0.574579
#
#           1             2         3         4             5             6  \
# 0 -3.472368  3.423497e-39 -4.019975 -2.682965  3.095561e-39  2.350940e-40
# 1 -1.032863  2.666148e-39 -3.083943 -0.214080  1.675793e-39 -5.305300e-40
# 2 -0.844022  1.648815e-39 -2.451156  0.017114 -9.188970e-40  2.053338e-39
# 3 -1.997322 -4.848840e-40 -3.875956 -0.883333 -1.451999e-39 -8.226740e-40
# 4 -0.706262  2.576583e-39 -2.607862 -0.230711 -2.665280e-40  1.637584e-39
#
#           7  ...             9        10            11            12  \
# 0 -2.235377  ... -4.595403e-39 -3.747526 -2.243110e-40 -4.803370e-40
# 1  0.470033  ... -2.014102e-39 -0.644985 -2.280837e-39  5.666230e-40
# 2 -0.687770  ...  1.666720e-39 -2.638187  1.417642e-39  3.506080e-40
# 3 -0.259665  ...  8.319800e-41  0.441326  4.066523e-39 -1.016244e-39
# 4 -0.094715  ...  1.248540e-40 -2.060443 -2.347249e-39  7.235490e-40
#
#              13        14        15        16        17  \
# 0 -2.707837e-39 -3.875355 -2.638527 -1.517044 -3.526651
# 1 -1.307451e-39 -1.202289 -0.816857  0.823061 -1.040545
# 2 -1.324915e-39 -0.342451 -0.532974  0.810412 -2.131410
# 3 -3.090698e-39 -1.631463 -1.706191  0.775801 -1.260036
# 4 -3.353733e-39 -1.342637 -0.839634  0.467398 -1.756306
#
#                                           dicom
# 0  91ea24c1-ddf8f918-0c579885-c0bf36ed-3a2b306a
# 1  35469b32-ecaab79e-6029f852-160bd61a-9e39d5bb
# 2  15a9cb0e-a198aa68-69378bf4-b2b1c36c-fd8020c2
# 3  884910a8-5d7a8bbd-1d59d71f-a97fa282-f7b9850f
# 4  ebdae94d-7ace4119-3ca77b0b-bc8b0cd9-77429e52
#
# [5 rows x 21 columns]

# %%
data2 = run_query(f"""
SELECT r.subject_id, dm.dicom, dm.StudyDate, h.hadm_id, h.admittime, h.dischtime
FROM `physionet-data.mimic_cxr.dicom_metadata_string` AS dm
JOIN `physionet-data.mimic_cxr.record_list` AS r ON r.dicom_id = dm.dicom
JOIN `physionet-data.mimiciv_2_2_hosp.admissions` AS h ON h.subject_id = r.subject_id
""")
print(data2)
# Out:
# /tmp/ipython-input-3359655996.py:7: FutureWarning: read_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.read_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.read_gbq
#   return pd.io.gbq.read_gbq(
#          subject_id                                         dicom StudyDate  \
# 0          18415616  75d67482-46fbfcfb-b9d3be10-98f1b1dd-ba9748dc  21640428
# 1          18415616  75d67482-46fbfcfb-b9d3be10-98f1b1dd-ba9748dc  21640428
# 2          18415616  91ea24c1-ddf8f918-0c579885-c0bf36ed-3a2b306a  21640428
# 3          18415616  91ea24c1-ddf8f918-0c579885-c0bf36ed-3a2b306a  21640428
# 4          19136768  69ea47d2-8e44c7ea-8fd5dada-9385460a-fd8863d2  21481021
# ...             ...                                           ...       ...
# 2509603    17956863  4baead16-4c878e7c-fcc6071d-e06ebfb2-61d25c4c  22060814
# 2509604    17956863  328fba1d-fb7a2246-f361ecc5-09c96079-48a89f06  22060927
# 2509605    17956863  328fba1d-fb7a2246-f361ecc5-09c96079-48a89f06  22060927
# 2509606    17956863  59218cf7-f2c291c7-25ed5f1f-1a839972-c93bb3b3  22060814
# 2509607    17956863  59218cf7-f2c291c7-25ed5f1f-1a839972-c93bb3b3  22060814
#
#           hadm_id           admittime           dischtime
# 0        29138337 2164-04-28 22:51:00 2164-04-30 16:20:00
# 1        21610375 2158-09-09 22:58:00 2158-09-16 16:57:00
# 2        29138337 2164-04-28 22:51:00 2164-04-30 16:20:00
# 3        21610375 2158-09-09 22:58:00 2158-09-16 16:57:00
# 4        27903990 2149-07-22 23:46:00 2149-07-23 19:20:00
# ...           ...                 ...                 ...
# 2509603  27809961 2206-03-20 20:49:00 2206-03-21 15:30:00
# 2509604  28747558 2206-09-27 23:30:00 2206-09-29 16:24:00
# 2509605  27809961 2206-03-20 20:49:00 2206-03-21 15:30:00
# 2509606  28747558 2206-09-27 23:30:00 2206-09-29 16:24:00
# 2509607  27809961 2206-03-20 20:49:00 2206-03-21 15:30:00
#
# [2509608 rows x 6 columns]

# %%
data2['time'] = pd.to_datetime(data2['StudyDate'], format='%Y%m%d', errors='coerce').dt.strftime('%Y-%m-%dT%H:%M:%S')
data2['admittime'] = pd.to_datetime(data2['admittime']).dt.strftime('%Y-%m-%dT00:00:00')
data2
# Out:
#          subject_id                                         dicom StudyDate  \
# 0          18415616  75d67482-46fbfcfb-b9d3be10-98f1b1dd-ba9748dc  21640428
# 1          18415616  75d67482-46fbfcfb-b9d3be10-98f1b1dd-ba9748dc  21640428
# 2          18415616  91ea24c1-ddf8f918-0c579885-c0bf36ed-3a2b306a  21640428
# 3          18415616  91ea24c1-ddf8f918-0c579885-c0bf36ed-3a2b306a  21640428
# 4          19136768  69ea47d2-8e44c7ea-8fd5dada-9385460a-fd8863d2  21481021
# ...             ...                                           ...       ...
# 2509603    17956863  4baead16-4c878e7c-fcc6071d-e06ebfb2-61d25c4c  22060814
# 2509604    17956863  328fba1d-fb7a2246-f361ecc5-09c96079-48a89f06  22060927
# 2509605    17956863  328fba1d-fb7a2246-f361ecc5-09c96079-48a89f06  22060927
# 2509606    17956863  59218cf7-f2c291c7-25ed5f1f-1a839972-c93bb3b3  22060814
# 2509607    17956863  59218cf7-f2c291c7-25ed5f1f-1a839972-c93bb3b3  22060814
#
#           hadm_id            admittime           dischtime  \
# 0        29138337  2164-04-28T00:00:00 2164-04-30 16:20:00
# 1        21610375  2158-09-09T00:00:00 2158-09-16 16:57:00
# 2        29138337  2164-04-28T00:00:00 2164-04-30 16:20:00
# 3        21610375  2158-09-09T00:00:00 2158-09-16 16:57:00
# 4        27903990  2149-07-22T00:00:00 2149-07-23 19:20:00
# ...           ...                  ...                 ...
# 2509603  27809961  2206-03-20T00:00:00 2206-03-21 15:30:00
# 2509604  28747558  2206-09-27T00:00:00 2206-09-29 16:24:00
# 2509605  27809961  2206-03-20T00:00:00 2206-03-21 15:30:00
# 2509606  28747558  2206-09-27T00:00:00 2206-09-29 16:24:00
# 2509607  27809961  2206-03-20T00:00:00 2206-03-21 15:30:00
#
#                         time
# 0        2164-04-28T00:00:00
# 1        2164-04-28T00:00:00
# 2        2164-04-28T00:00:00
# 3        2164-04-28T00:00:00
# 4        2148-10-21T00:00:00
# ...                      ...
# 2509603  2206-08-14T00:00:00
# 2509604  2206-09-27T00:00:00
# 2509605  2206-09-27T00:00:00
# 2509606  2206-08-14T00:00:00
# 2509607  2206-08-14T00:00:00
#
# [2509608 rows x 7 columns]

# %%
#Lọc Thời gian
data2 = data2[(data2['admittime'] <= data2['time']) & (data2['time'] <= data2['dischtime'])]

# %%
# Xóa các hàng 'hadm_id' trùng lặp, chỉ giữ lại lần xuất hiện đầu tiên
data2 = data2.drop_duplicates(subset='dicom', keep='first')

print(data2)
# Out:
#          subject_id                                         dicom StudyDate  \
# 0          18415616  75d67482-46fbfcfb-b9d3be10-98f1b1dd-ba9748dc  21640428
# 2          18415616  91ea24c1-ddf8f918-0c579885-c0bf36ed-3a2b306a  21640428
# 13         19136768  c2822cd9-785880dd-b21df2f4-feae6873-a3dbcc34  21501224
# 27         19136768  35469b32-ecaab79e-6029f852-160bd61a-9e39d5bb  21510408
# 33         19136768  aad41f8e-432a7f56-264d490c-740a1fa6-94f4f537  21510408
# ...             ...                                           ...       ...
# 2509593    15007487  81f647b5-856ae069-e0941845-c6ddb0f6-e9a9aaec  21421214
# 2509594    15007487  2acfc474-14dcc92e-4c225ec7-4451198e-601be5b0  21421213
# 2509595    15007487  4690a275-0ffc1451-af9921ce-cebf8df2-24a0236a  21421215
# 2509596    17956863  aaf308c6-4bdb0059-affc2594-f26cb1f6-702c5e9d  22060927
# 2509604    17956863  328fba1d-fb7a2246-f361ecc5-09c96079-48a89f06  22060927
#
#           hadm_id            admittime           dischtime  \
# 0        29138337  2164-04-28T00:00:00 2164-04-30 16:20:00
# 2        29138337  2164-04-28T00:00:00 2164-04-30 16:20:00
# 13       29901658  2150-12-24T00:00:00 2150-12-27 13:00:00
# 27       26451475  2151-04-08T00:00:00 2151-04-10 17:45:00
# 33       26451475  2151-04-08T00:00:00 2151-04-10 17:45:00
# ...           ...                  ...                 ...
# 2509593  28588271  2142-12-11T00:00:00 2142-12-19 14:44:00
# 2509594  28588271  2142-12-11T00:00:00 2142-12-19 14:44:00
# 2509595  28588271  2142-12-11T00:00:00 2142-12-19 14:44:00
# 2509596  28747558  2206-09-27T00:00:00 2206-09-29 16:24:00
# 2509604  28747558  2206-09-27T00:00:00 2206-09-29 16:24:00
#
#                         time
# 0        2164-04-28T00:00:00
# 2        2164-04-28T00:00:00
# 13       2150-12-24T00:00:00
# 27       2151-04-08T00:00:00
# 33       2151-04-08T00:00:00
# ...                      ...
# 2509593  2142-12-14T00:00:00
# 2509594  2142-12-13T00:00:00
# 2509595  2142-12-15T00:00:00
# 2509596  2206-09-27T00:00:00
# 2509604  2206-09-27T00:00:00
#
# [236320 rows x 7 columns]

# %%
# Merge the two DataFrames on 'dicom'
data_f = data.merge(data2, on='dicom', how='inner')
print(data_f)
# Out:
#         Unnamed: 0                                         file_name  \
# 0                0  91ea24c1-ddf8f918-0c579885-c0bf36ed-3a2b306a.jpg
# 1                1  35469b32-ecaab79e-6029f852-160bd61a-9e39d5bb.jpg
# 2                2  15a9cb0e-a198aa68-69378bf4-b2b1c36c-fd8020c2.jpg
# 3                3  884910a8-5d7a8bbd-1d59d71f-a97fa282-f7b9850f.jpg
# 4                4  ebdae94d-7ace4119-3ca77b0b-bc8b0cd9-77429e52.jpg
# ...            ...                                               ...
# 112026      145590  68d34ebb-d6a26d81-95dc7596-cf6b9b52-837fa967.jpg
# 112027      145592  d549956e-a4caae3e-978d2446-f5280ec9-ffc321ee.jpg
# 112028      145593  95fd7365-ef0d4f84-d108a31f-d847bc31-a28109d0.jpg
# 112029      145594  304b0b21-0a8d3feb-313fac0e-432a4904-efb3dc6b.jpg
# 112030      145595  32eb07cd-6dba43b7-858fb880-1a9bc182-6360bd42.jpg
#
#                0         1             2         3         4             5  \
# 0      -1.920675 -3.472368  3.423497e-39 -4.019975 -2.682965  3.095561e-39
# 1       0.088068 -1.032863  2.666148e-39 -3.083943 -0.214080  1.675793e-39
# 2      -0.521883 -0.844022  1.648815e-39 -2.451156  0.017114 -9.188970e-40
# 3       0.401914 -1.997322 -4.848840e-40 -3.875956 -0.883333 -1.451999e-39
# 4      -0.574579 -0.706262  2.576583e-39 -2.607862 -0.230711 -2.665280e-40
# ...          ...       ...           ...       ...       ...           ...
# 112026  3.085485  1.823781 -3.876314e-39 -2.338892  1.476944 -7.264288e-39
# 112027  1.454602 -0.164013  1.914566e-39 -3.532086  0.827811 -1.016154e-39
# 112028  1.501685  0.285801 -8.879230e-40 -2.694008  1.185740 -2.103790e-39
# 112029  0.827898  0.113829  7.857100e-40 -2.766041  0.392817 -6.768330e-40
# 112030  0.672758 -0.135704  2.130911e-39 -2.727540  0.562757  7.518890e-40
#
#                    6         7  ...        15        16        17  \
# 0       2.350940e-40 -2.235377  ... -2.638527 -1.517044 -3.526651
# 1      -5.305300e-40  0.470033  ... -0.816857  0.823061 -1.040545
# 2       2.053338e-39 -0.687770  ... -0.532974  0.810412 -2.131410
# 3      -8.226740e-40 -0.259665  ... -1.706191  0.775801 -1.260036
# 4       1.637584e-39 -0.094715  ... -0.839634  0.467398 -1.756306
# ...              ...       ...  ...       ...       ...       ...
# 112026 -4.482567e-39  3.238685  ...  1.052956  3.511806  2.391164
# 112027 -2.635146e-39  1.643208  ... -0.636985  1.958849  0.358582
# 112028 -1.126459e-39  1.463032  ...  0.173350  2.002823  0.077036
# 112029  1.230189e-39  1.102925  ... -0.197376  1.581476 -0.447229
# 112030  1.560039e-39  1.046239  ... -1.130504  1.117469 -1.485039
#
#                                                dicom  subject_id  StudyDate  \
# 0       91ea24c1-ddf8f918-0c579885-c0bf36ed-3a2b306a    18415616   21640428
# 1       35469b32-ecaab79e-6029f852-160bd61a-9e39d5bb    19136768   21510408
# 2       15a9cb0e-a198aa68-69378bf4-b2b1c36c-fd8020c2    19136768   21490722
# 3       884910a8-5d7a8bbd-1d59d71f-a97fa282-f7b9850f    19136768   21501224
# 4       ebdae94d-7ace4119-3ca77b0b-bc8b0cd9-77429e52    19136768   21501224
# ...                                              ...         ...        ...
# 112026  68d34ebb-d6a26d81-95dc7596-cf6b9b52-837fa967    17925184   21410618
# 112027  d549956e-a4caae3e-978d2446-f5280ec9-ffc321ee    11984693   21431122
# 112028  95fd7365-ef0d4f84-d108a31f-d847bc31-a28109d0    18632125   21270726
# 112029  304b0b21-0a8d3feb-313fac0e-432a4904-efb3dc6b    13042648   21570414
# 112030  32eb07cd-6dba43b7-858fb880-1a9bc182-6360bd42    13964474   21640316
#
#          hadm_id            admittime           dischtime                 time
# 0       29138337  2164-04-28T00:00:00 2164-04-30 16:20:00  2164-04-28T00:00:00
# 1       26451475  2151-04-08T00:00:00 2151-04-10 17:45:00  2151-04-08T00:00:00
# 2       27903990  2149-07-22T00:00:00 2149-07-23 19:20:00  2149-07-22T00:00:00
# 3       29901658  2150-12-24T00:00:00 2150-12-27 13:00:00  2150-12-24T00:00:00
# 4       29901658  2150-12-24T00:00:00 2150-12-27 13:00:00  2150-12-24T00:00:00
# ...          ...                  ...                 ...                  ...
# 112026  20494256  2141-05-21T00:00:00 2141-06-26 15:10:00  2141-06-18T00:00:00
# 112027  23064786  2143-11-17T00:00:00 2143-12-06 14:39:00  2143-11-22T00:00:00
# 112028  27455459  2127-07-25T00:00:00 2127-07-29 12:19:00  2127-07-26T00:00:00
# 112029  26929856  2157-04-14T00:00:00 2157-04-15 13:50:00  2157-04-14T00:00:00
# 112030  25183055  2164-03-08T00:00:00 2164-04-08 16:15:00  2164-03-16T00:00:00
#
# [112031 rows x 27 columns]

# %%
# Drop duplicate 'hadm_id' rows, keeping only the first occurrence
data_f = data_f.drop_duplicates(subset='hadm_id', keep='first')

# %%
data_f.to_csv('x_ray_data.csv', index=False)
files.download('x_ray_data.csv')

# %%
# !ls -l
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Oct 28 13:34 sample_data
